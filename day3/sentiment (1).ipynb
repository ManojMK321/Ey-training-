# %%
"""
Day 1 Coding Activity — Sentiment Analysis with Hugging Face
EY Workshop | Participant: Manoj Kumar
"""

from transformers import pipeline

#  TODO 1: Initialise a sentiment-analysis pipeline
classifier = pipeline("sentiment-analysis")

# Sample sentences relevant to consulting work
sentences = [
    "The client was very satisfied with the delivery.",
    "The project is significantly over budget and behind schedule.",
    "The new regulatory framework presents both risks and opportunities.",
    "Our team successfully met all key milestones ahead of deadline."  #  TODO 2 (your sentence)
]

#  Function to get sentiment
def getSentiment(classifier, text):
    result = classifier(text)
    label = result[0]['label']
    score = result[0]['score']
    return label, score

#  TODO 3: Run classifier and print results
for sentence in sentences:
    label, score = getSentiment(classifier, sentence)
    print(f'"{sentence[:50]}..." → {label} ({score:.4f})')
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights: 100%|██████████| 104/104 [00:00<00:00, 5148.27it/s]
# "The client was very satisfied with the delivery...." → POSITIVE (0.9993)
# "The project is significantly over budget and behin..." → NEGATIVE (0.9997)
# "The new regulatory framework presents both risks a..." → POSITIVE (0.9911)
# "Our team successfully met all key milestones ahead..." → POSITIVE (0.9998)

# %%
# Out:
# "The client was very satisfied with the delivery...." → POSITIVE (0.9993)
# "The project is significantly over budget and behin..." → NEGATIVE (0.9997)
# "The new regulatory framework presents both risks a..." → POSITIVE (0.9911)
# "Our team successfully met all key milestones ahead..." → POSITIVE (0.9998)
